# %%
# !pip install faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 4.8 MB/s  0:00:00
# ...

# %%
# Re-run the data generation script to ensure files exist
# data_generator.py
import pandas as pd
import random
from faker import Faker
import json
from ast import literal_eval

fake = Faker('en_IN')

# Base pools and dynamic expansion helpers
BASE_SKILLS = [
    # Tech & data
    'Python','Java','C++','C','JavaScript','TypeScript','Go','Rust','SQL','NoSQL','HTML','CSS','React','Angular','Vue','Django','Flask','Spring','Node.js','Express',
    'Data Analysis','Data Engineering','Machine Learning','Deep Learning','NLP','Computer Vision','Statistics','Excel','Power BI','Tableau','R','SPSS','STATA','MATLAB',
    'Cloud','AWS','Azure','GCP','DevOps','CI/CD','Docker','Kubernetes','Linux','Git','GitHub','GitLab','Bash','Powershell',
    'Networking','Cybersecurity','Penetration Testing','SIEM','Vulnerability Assessment','ISO 27001',
    'UI/UX','Figma','Adobe XD','Canva','Graphic Design','Design Systems','Accessibility',
    # Business & generic
    'Product Management','Project Management','Agile','Scrum','Jira','Confluence','Documentation','Technical Writing','Business Analysis','Requirements Gathering',
    'Marketing','Digital Marketing','SEO','SEM','Content Writing','Copywriting','Social Media','Branding','Email Marketing','Google Analytics',
    'Sales','Inside Sales','Field Sales','Lead Generation','CRM','Salesforce','HubSpot','Customer Relationship',
    'Finance','Accounting','Auditing','Taxation','Investment Research','Financial Modeling','Tally','GST','Bookkeeping',
    'Operations','Supply Chain','Logistics','Procurement','Inventory Management','Warehouse Operations','Cold Chain',
    'HR','Recruitment','Talent Acquisition','Payroll','L&D','Compliance','Labor Laws','Employee Engagement',
    'Quality Assurance','Manual Testing','Automation Testing','Selenium','JMeter','Postman','Six Sigma','Lean','5S','ISO 9001',
    # Soft skills & digital literacy
    'Communication','Presentation','Public Speaking','Teamwork','Leadership','Problem Solving','Critical Thinking','Time Management','Adaptability','Creativity',
    'Customer Service','Basic Computer Skills','MS Word','MS Excel','MS PowerPoint','Typing','Data Entry',
    # Vocational & sector-specific
    'AutoCAD','SolidWorks','CATIA','CAD','CAM','CNC','3D Printing','PLC','SCADA','Industrial Safety',
    'Electrical Wiring','Electronics Repair','PCB Design','Arduino','Raspberry Pi','IoT','Embedded Systems','VLSI Basics',
    'Welding','Carpentry','Plumbing','Masonry','Painting','Solar Installation','Wind Turbine Basics',
    'GIS','Remote Sensing','Surveying','Drones','UAV Operation',
    'Food Safety','HACCP','FSSAI Compliance','Food Processing','Packaging',
    'Pharmacy Assistance','Phlebotomy','Nursing Assistance','Medical Coding','EHR Systems','Telemedicine Support','Laboratory Technician',
    'Retail Operations','Cashier','POS Systems','Merchandising','Store Management',
    'Insurance Underwriting','Claims Processing','KYC','AML','Risk Assessment','Microfinance',
    'Rural Outreach','Field Survey','Social Work','NGO Program Support','CSR Implementation','Community Mobilization',
    'PowerApps','Power Automate','SharePoint','ServiceNow','Zoho',
]
BASE_INDUSTRIES = [
    # Core sectors
    'Technology','Finance','Healthcare','Manufacturing','Retail','Education','Media','Consulting','Telecommunications','Energy','Transportation',
    'Agriculture','Automotive','Pharmaceuticals','Biotechnology','Aerospace','Defense','Hospitality','Tourism','Real Estate','Construction',
    # Services & platforms
    'E-commerce','Logistics','Warehousing','Cold Chain','Courier','BPO/ITES','KPO','Shared Services','Public Sector','Non-Profit','Banking','Insurance',
    # Emerging & domain
    'FinTech','EdTech','HealthTech','GovTech','AgriTech','Food Processing','CleanTech','Waste Management','Water & Sanitation','Environmental Services','Climate & Sustainability',
    'Renewable Energy','Solar','Wind','Oil & Gas','Mining','Metals',
    # Rural & traditional
    'Dairy','Poultry','Fisheries','Horticulture','Handloom','Handicrafts','Textiles','Leather',
    # Urban infra & mobility
    'Smart Cities','Urban Development','Roads & Highways','Railways','Metro Rail','Ports & Shipping','Aviation',
    # Social & governance
    'Public Health','Social Welfare','Disaster Management','Rural Development','Panchayati Raj','MSME','Startups & Incubation','CSR',
    # Lifestyle & services
    'Food & Beverage','Sports','Entertainment','Gaming','Legal','Advertising','Marketing Services','Research','Analytics','Cybersecurity','Cloud Services','Beauty & Wellness','Event Management',
]
BASE_TIER1_CITIES = ['Mumbai','Delhi','Bengaluru','Chennai','Kolkata','Hyderabad','Pune','Ahmedabad']
BASE_TIER2_CITIES = [
    'Jaipur','Surat','Lucknow','Kanpur','Nagpur','Indore','Thane','Bhopal','Visakhapatnam','Vadodara','Firozabad','Ludhiana','Agra','Nashik','Faridabad','Meerut',
    'Rajkot','Kalyan','Vasai-Virar','Varanasi','Srinagar','Aurangabad','Dhanbad','Amritsar','Navi Mumbai','Allahabad','Ranchi','Haora','Coimbatore','Jabalpur','Gwalior',
    'Vijayawada','Jodhpur','Madurai','Raipur','Kota','Guwahati','Chandigarh','Solapur','Hubli–Dharwad','Bareilly','Moradabad','Mysore','Gurgaon','Aligarh','Jalandhar',
    'Tiruchirappalli','Bhubaneswar','Salem','Warangal','Mira-Bhayandar','Thiruvananthapuram','Bhiwandi','Saharanpur','Guntur','Amravati','Bikaner','Noida','Jamshedpur'
]
BASE_TIER3_CITIES = [
    'Ujjain','Nellore','Jamnagar','Belgaum','Mangalore','Ambattur','Tirunelveli','Malegaon','Gaya','Jalgaon','Udaipur','Maheshtala','Tirupati','Davanagere','Kozhikode',
    'Akola','Kurnool','Bokaro','Bellary','Patiala','South Dumdum','Aizawl','Sambalpur','Nadiad','Kakinada','Rajahmundry','Shimoga','Mysuru','Siliguri','Durgapur',
    'Panipat','Bhiwani','Rohtak','Sonipat','Yamunanagar','Ambala','Hisar','Karnal','Rewari','Kurukshetra','Palwal','Kaithal','Sirsa','Fatehabad','Jhajjar','Panvel'
]

TARGET_SKILLS_COUNT = 200
TARGET_INDUSTRIES_COUNT = 100
TARGET_CITIES_COUNT = 350

# Build expanded pools deterministically
random.seed(42)

def build_skills_pool():
    pool = list(dict.fromkeys(BASE_SKILLS))
    idx = 0
    while len(pool) < TARGET_SKILLS_COUNT:
        idx += 1
        pool.append(f"Skill_{idx:03d}")
    return pool

def build_industries_pool():
    pool = list(dict.fromkeys(BASE_INDUSTRIES))
    idx = 0
    while len(pool) < TARGET_INDUSTRIES_COUNT:
        idx += 1
        pool.append(f"Industry_{idx:03d}")
    return pool

def build_cities_pool():
    base = list(dict.fromkeys(BASE_TIER1_CITIES + BASE_TIER2_CITIES + BASE_TIER3_CITIES))
    # Fast deterministic fill to target size without Faker overhead
    while len(base) < TARGET_CITIES_COUNT:
        base.append(f"City_{len(base)+1:03d}")
    return base

SKILLS_POOL = build_skills_pool()
INDUSTRIES_POOL = build_industries_pool()
CITIES_POOL = build_cities_pool()

# Aspirations and roles
BASE_ASPIRATIONS = [
    'Software Developer','Data Analyst','Data Scientist','ML Engineer','DevOps Engineer','Cloud Engineer','UI/UX Designer','Product Manager','Project Manager',
    'Business Analyst','Marketing Associate','Digital Marketer','Content Writer','Copywriter','Finance Intern','Financial Analyst','HR Assistant','Recruiter',
    'Operations Associate','Supply Chain Analyst','QA Engineer','Automation Tester','Cybersecurity Analyst','Network Engineer','Technical Support','Customer Support'
]

def build_aspirations_pool():
    pool = list(dict.fromkeys(BASE_ASPIRATIONS))
    idx = 0
    while len(pool) < 120:
        idx += 1
        pool.append(f"Aspiration_{idx:03d}")
    return pool

ASPIRATIONS_POOL = build_aspirations_pool()
ROLES_POOL = list(dict.fromkeys(BASE_ASPIRATIONS + ['Content Strategist','Full Stack Developer','Mobile App Developer','Data Engineer','Growth Marketer']))
COMPANIES = ['TCS','Infosys','Wipro','HCL','HDFC Bank','ICICI Bank','Reliance','Mahindra','L&T','Bajaj','Aditya Birla','Tata Steel','Maruti Suzuki','Tech Mahindra','Cognizant']


def generate_students(n=1500):
    students = []
    for i in range(n):
        student = {
            'id': f'STU{i:03d}',
            'name': fake.name(),
            'age': random.randint(18, 25),
            'education': random.choice(['B.Tech','B.Sc','BBA','B.Com','MBA','BA','BCA','MCA']),
            'skills': random.sample(SKILLS_POOL, k=random.randint(3, 8)),
            'aspirations': random.sample(ASPIRATIONS_POOL, k=random.randint(1, 3)),
            'location': random.choice(CITIES_POOL),
            'industry_interest': random.choice(INDUSTRIES_POOL),
            'experience_months': random.randint(0, 24)
        }
        students.append(student)
    return pd.DataFrame(students)


def generate_internships(n=1500):
    internships = []
    for i in range(n):
        internship = {
            'id': f'INT{i:03d}',
            'company': random.choice(COMPANIES),
            'role': random.choice(ROLES_POOL),
            'location': random.choice(CITIES_POOL),
            'industry': random.choice(INDUSTRIES_POOL),
            'required_skills': random.sample(SKILLS_POOL, k=random.randint(2, 6)),
            'duration_months': random.choice([3, 6, 12]),
            'stipend': random.randint(5000, 25000)
        }
        internships.append(internship)
    return pd.DataFrame(internships)

students_df = generate_students(1500)
internships_df = generate_internships(1500)

students_df.to_csv('./students.csv', index=False)
internships_df.to_csv('./internships.csv', index=False)

print("✅ Data generated successfully!")
print(f"Students: {len(students_df)}, Internships: {len(internships_df)}")

# Load the generated dataframes
students_df = pd.read_csv('students.csv')
internships_df = pd.read_csv('internships.csv')

# Inspect data
print("Students DataFrame Info:")
students_df.info()
print("\nStudents DataFrame Head:")
display(students_df.head())
print("\nStudents Missing Values:")
print(students_df.isnull().sum())

print("\nInternships DataFrame Info:")
internships_df.info()
print("\nInternships DataFrame Head:")
display(internships_df.head())
print("\nInternships Missing Values:")
print(internships_df.isnull().sum())

# Convert list-like string columns to clean, comma-joined strings using safe parsing
for col in ['skills','aspirations']:
    if students_df[col].dtype == object:
        students_df[col] = students_df[col].apply(lambda x: ', '.join(literal_eval(x)) if isinstance(x, str) and x.startswith('[') else (x if isinstance(x, str) else ''))

if internships_df['required_skills'].dtype == object:
    internships_df['required_skills'] = internships_df['required_skills'].apply(lambda x: ', '.join(literal_eval(x)) if isinstance(x, str) and x.startswith('[') else (x if isinstance(x, str) else ''))

print("\nStudents DataFrame with processed skills & aspirations:")
display(students_df.head())
print("\nInternships DataFrame with processed required_skills:")
display(internships_df.head())
# Out:
# ✅ Data generated successfully!
# Students: 1500, Internships: 1500
# Students DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1500 non-null   object
#  1   name               1500 non-null   object
#  2   age                1500 non-null   int64
#  3   education          1500 non-null   object
#  4   skills             1500 non-null   object
#  5   aspirations        1500 non-null   object
#  6   location           1500 non-null   object
#  7   industry_interest  1500 non-null   object
#  8   experience_months  1500 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 105.6+ KB
#
# Students DataFrame Head:
#        id                name  age education  \
# 0  STU000    Isaiah Natarajan   19    B.Tech
# 1  STU001  Patrick Chatterjee   21     B.Com
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Build field-specific text features
students_df['skills_asp_text'] = students_df.apply(
    lambda row: f"{row['skills']} {row['aspirations']}", axis=1
)
internships_df['reqskills_role_text'] = internships_df.apply(
    lambda row: f"{row['required_skills']} {row['role']}", axis=1
)

students_df['industry_text'] = students_df['industry_interest'].apply(lambda v: f"industry:{v}")
internships_df['industry_text'] = internships_df['industry'].apply(lambda v: f"industry:{v}")

students_df['location_text'] = students_df['location'].apply(lambda v: f"location:{v}")
internships_df['location_text'] = internships_df['location'].apply(lambda v: f"location:{v}")

# Vectorizers per field
vec_main = TfidfVectorizer(ngram_range=(1, 2), min_df=2)
vec_industry = TfidfVectorizer()
vec_location = TfidfVectorizer()

# Fit on combined corpora for each field
main_corpus = students_df['skills_asp_text'].tolist() + internships_df['reqskills_role_text'].tolist()
industry_corpus = students_df['industry_text'].tolist() + internships_df['industry_text'].tolist()
location_corpus = students_df['location_text'].tolist() + internships_df['location_text'].tolist()

main_matrix = vec_main.fit_transform(main_corpus)
industry_matrix = vec_industry.fit_transform(industry_corpus)
location_matrix = vec_location.fit_transform(location_corpus)

# Split student/internship parts
student_main = main_matrix[:len(students_df)]
intern_main = main_matrix[len(students_df):]

student_industry = industry_matrix[:len(students_df)]
intern_industry = industry_matrix[len(students_df):]

student_location = location_matrix[:len(students_df)]
intern_location = location_matrix[len(students_df):]

# Field-wise cosine similarities
sim_main = cosine_similarity(student_main, intern_main)
sim_industry = cosine_similarity(student_industry, intern_industry)
sim_location = cosine_similarity(student_location, intern_location)

# Weighted combination (tuneable)
W_MAIN, W_INDUSTRY, W_LOCATION = 0.6, 0.2, 0.2
similarity_matrix = (W_MAIN * sim_main) + (W_INDUSTRY * sim_industry) + (W_LOCATION * sim_location)

print("Shapes -> main:", student_main.shape, intern_main.shape)
print("Shapes -> industry:", student_industry.shape, intern_industry.shape)
print("Shapes -> location:", student_location.shape, intern_location.shape)
print("Final similarity matrix:", similarity_matrix.shape)
# Out:
# Shapes -> main: (1500, 2780) (1500, 2780)
# Shapes -> industry: (1500, 121) (1500, 121)
# Shapes -> location: (1500, 355) (1500, 355)
# Final similarity matrix: (1500, 1500)

# %%
# Similarity already computed using weighted multi-field approach above
print("Shape of similarity matrix:", similarity_matrix.shape)
# Out:
# Shape of similarity matrix: (1500, 1500)

# %%
import numpy as np

# Number of recommendations to generate for each student
N = 5

# Dictionary to store recommendations for each student
student_recommendations = {}

# Iterate through each student's similarity scores
for i in range(len(students_df)):
    student_id = students_df.loc[i, 'id']
    # Get the similarity scores for the current student
    student_similarity_scores = similarity_matrix[i, :]

    # Get the indices of the top N internships with the highest similarity scores
    top_internship_indices = np.argsort(student_similarity_scores)[::-1][:N]

    # Get the details of the recommended internships
    recommended_internships = internships_df.iloc[top_internship_indices].copy()
    recommended_internships['similarity'] = student_similarity_scores[top_internship_indices]
    recommended_internships = recommended_internships.to_dict('records')

    # Store the recommendations
    student_recommendations[student_id] = recommended_internships

# Print recommendations for a few sample students
sample_student_ids = list(student_recommendations.keys())[:5]

print("Sample Internship Recommendations:")
for student_id in sample_student_ids:
    stu = students_df[students_df['id'] == student_id].iloc[0]
    print(f"\nRecommendations for Student ID: {student_id} | Location: {stu['location']} | Aspirations: {stu['aspirations']}")
    for rec in student_recommendations[student_id]:
        print(f"  - {rec['role']} at {rec['company']} in {rec['location']} (Industry: {rec['industry']})")
        print(f"    Skills: {rec['required_skills']} | Score: {rec['similarity']:.3f}")
# Out:
# Sample Internship Recommendations:
#
# Recommendations for Student ID: STU000 | Location: Visakhapatnam | Aspirations: Digital Marketer, Aspiration_050, Aspiration_029
#   - Digital Marketer at Aditya Birla in City_330 (Industry: Manufacturing)
#     Skills: Food Safety, Microfinance, Flask | Score: 0.322
#   - Project Manager at Aditya Birla in Visakhapatnam (Industry: Startups & Incubation)
#     Skills: Raspberry Pi, GitLab, EHR Systems, Excel, JMeter, Communication | Score: 0.223
#   - Cybersecurity Analyst at TCS in City_138 (Industry: Manufacturing)
#     Skills: Rural Outreach, Supply Chain, Bookkeeping, Store Management | Score: 0.216
#   - Operations Associate at Tech Mahindra in Jodhpur (Industry: Telecommunications)
#     Skills: Claims Processing, Project Management | Score: 0.213
#   - Copywriter at Reliance in Visakhapatnam (Industry: Research)
#     Skills: NoSQL, Confluence | Score: 0.206
#
# ...

# %%
import random

# Select a few diverse student IDs
sample_student_ids = random.sample(list(student_recommendations.keys()), 5)

print("Qualitative Evaluation of Recommendations:")
print("="*40)

for student_id in sample_student_ids:
    # Get student profile
    student_profile = students_df[students_df['id'] == student_id].iloc[0]

    print(f"\nStudent Profile (ID: {student_id}):")
    print(f"  Skills: {student_profile['skills']}")
    print(f"  Aspirations: {student_profile['aspirations']}")
    print(f"  Education: {student_profile['education']}")
    print(f"  Location: {student_profile['location']}")
    print(f"  Industry Interest: {student_profile['industry_interest']}")

    print("\nRecommended Internships:")
    recommendations = student_recommendations[student_id]
    if recommendations:
        for i, rec in enumerate(recommendations):
            print(f"  {i+1}. {rec['role']} at {rec['company']}")
            print(f"     Location: {rec['location']}, Industry: {rec['industry']}")
            print(f"     Required Skills: {rec['required_skills']} | Score: {rec['similarity']:.3f}")
    else:
        print("  No recommendations found.")

print("\n" + "="*40)
print("Manual Inspection Observations:")
print("The multi-field weighted similarity (skills+aspirations, industry, location) aims to balance skill fit with student aspirations and alignment on industry/location.")
print("Tune weights W_MAIN, W_INDUSTRY, W_LOCATION if certain aspects need more/less influence.")
# Out:
# Qualitative Evaluation of Recommendations:
# ...
#
# Student Profile (ID: STU1059):
#   Skills: Design Systems, SEM, HACCP, Presentation, Public Speaking
#   Aspirations: Aspiration_025, Aspiration_051, Aspiration_020
#   Education: BBA
#   Location: City_279
#   Industry Interest: Railways
#
# Recommended Internships:
#   1. Product Manager at HDFC Bank
#      Location: City_222, Industry: Railways
#      Required Skills: HR, Git, Masonry, Statistics, C, Presentation | Score: 0.263
#   2. Business Analyst at TCS
#      Location: City_162, Industry: Railways
#      Required Skills: EHR Systems, Cloud, ISO 9001, Statistics, Requirements Gathering, Automation Testing | Score: 0.223
#   3. Supply Chain Analyst at L&T
#      Location: City_279, Industry: Handloom
#      Required Skills: GST, Spring | Score: 0.206
#   4. Copywriter at Tech Mahindra
#      Location: City_279, Industry: Horticulture
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Re-build student profile text with education level included (already done in previous step)
# students_df['student_profile_text'] = students_df.apply(
#     lambda row: f"{row['skills']} {row['education']} {row['location']} {row['industry_interest']}", axis=1
# )

# Re-build internship text data (already done in previous step)
# internships_df['internship_profile_text'] = internships_df.apply(
#     lambda row: f"{row['required_skills']} {row['location']} {row['industry']}", axis=1
# )

# Combine all text data for fitting the vectorizer
all_text_data = students_df['student_profile_text'].tolist() + internships_df['internship_profile_text'].tolist()

# TF-IDF Vectorization with n-grams (unigrams and bigrams)
vectorizer_ngram = TfidfVectorizer(ngram_range=(1, 2))
tfidf_matrix_ngram = vectorizer_ngram.fit_transform(all_text_data)

# Separate the TF-IDF matrices for students and internships
student_tfidf_matrix_ngram = tfidf_matrix_ngram[:len(students_df)]
internship_tfidf_matrix_ngram = tfidf_matrix_ngram[len(students_df):]

print("Shape of student TF-IDF matrix with n-grams:", student_tfidf_matrix_ngram.shape)
print("Shape of internship TF-IDF matrix with n-grams:", internship_tfidf_matrix_ngram.shape)

# One-hot encode education level for students
# Identify unique education levels
education_levels = students_df['education'].unique().reshape(-1, 1)

# Initialize OneHotEncoder
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# Fit and transform the education levels
education_onehot = encoder.fit_transform(students_df[['education']])

# Convert to DataFrame for easier handling
education_onehot_df = pd.DataFrame(education_onehot, columns=[f'education_{level}' for level in encoder.categories_[0]])

# Combine TF-IDF features with one-hot encoded education features for students
# Ensure index alignment
student_features_combined = np.hstack((student_tfidf_matrix_ngram.toarray(), education_onehot_df.values))

print("Shape of combined student features:", student_features_combined.shape)

# For internships, we only have the TF-IDF features from the text data
internship_features_combined = internship_tfidf_matrix_ngram.toarray()

print("Shape of combined internship features:", internship_features_combined.shape)

# Recalculate cosine similarity with combined features
# Note: Cosine similarity works best when features are in the same space.
# Combining TF-IDF (sparse, potentially high-dimensional) with one-hot (dense, low-dimensional)
# directly might not be optimal. A more advanced approach could involve different models
# or feature scaling/weighting. For this refinement step, we'll proceed with direct combination
# for demonstration, acknowledging this limitation.

# To calculate similarity, both matrices need to have the same number of features.
# The internship features do not have the one-hot encoded education levels.
# We need to decide how to handle this discrepancy for similarity calculation.
# Option 1: Only use the TF-IDF features (already done in previous steps, refining with n-grams here).
# Option 2: Find a way to represent education in internships (not directly available).
# Option 3: Use a different model that can handle mixed feature types.

# Given the subtask instructions to refine features and then re-run recommendations,
# and the lack of education data for internships, we will stick to using
# the enhanced text features (with n-grams) for both students and internships
# for the cosine similarity calculation, as this is a direct improvement on the
# existing TF-IDF approach. The one-hot encoding of education is a valid feature
# engineering step for students, but its direct use in cosine similarity with
# internships is limited without a corresponding feature for internships.

# Recalculate cosine similarity using the TF-IDF matrix with n-grams
similarity_matrix_refined = cosine_similarity(student_tfidf_matrix_ngram, internship_tfidf_matrix_ngram)

print("Shape of refined similarity matrix (with n-grams):", similarity_matrix_refined.shape)

# Update the similarity matrix variable for the next steps
similarity_matrix = similarity_matrix_refined

# %%
import numpy as np
import random

# Use the existing weighted similarity matrix
N = 5
student_recommendations_refined = {}

for i in range(len(students_df)):
    student_id = students_df.loc[i, 'id']
    scores = similarity_matrix[i, :]
    top_idx = np.argsort(scores)[::-1][:N]
    recs = internships_df.iloc[top_idx].copy()
    recs['similarity'] = scores[top_idx]
    student_recommendations_refined[student_id] = recs.to_dict('records')

# Qualitative check with the same style output
sample_student_ids = random.sample(list(student_recommendations_refined.keys()), 5)

print("Qualitative Evaluation of Refined Recommendations (weighted multi-field):")
print("="*60)

for student_id in sample_student_ids:
    student_profile = students_df[students_df['id'] == student_id].iloc[0]

    print(f"\nStudent Profile (ID: {student_id}):")
    print(f"  Skills: {student_profile['skills']}")
    print(f"  Education: {student_profile['education']}")
    print(f"  Location: {student_profile['location']}")
    print(f"  Industry Interest: {student_profile['industry_interest']}")

    print("\nRecommended Internships (Refined):")
    recommendations_refined = student_recommendations_refined[student_id]
    if recommendations_refined:
        for i, rec in enumerate(recommendations_refined):
            print(f"  {i+1}. {rec['role']} at {rec['company']}")
            print(f"     Location: {rec['location']}, Industry: {rec['industry']}")
            print(f"     Required Skills: {rec['required_skills']}")
    else:
        print("  No refined recommendations found.")

print("\n" + "="*60)
print("Manual Inspection Observations (Refined Recommendations):")
print("Comparing these recommendations to the previous ones, the inclusion of n-grams in TF-IDF may have captured more nuanced relationships between terms.")
print("Look for recommendations that might be more specific or better aligned with combinations of skills or industries mentioned in the student profile.")
print("Note if the rankings of internships have changed significantly or if different internships appear in the top N.")
# Out:
# Qualitative Evaluation of Refined Recommendations (weighted multi-field):
# ...
#
# Student Profile (ID: STU974):
#   Skills: CRM, Selenium, Azure, C
#   Education: BBA
#   Location: Lucknow
#   Industry Interest: Logistics
#
# Recommended Internships (Refined):
#   1. Automation Tester at Bajaj
#      Location: City_120, Industry: Logistics
#      Required Skills: Nursing Assistance, CRM
#   2. Product Manager at L&T
#      Location: Lucknow, Industry: Industry_001
#      Required Skills: Selenium, HubSpot, Sales, AutoCAD, AWS
#   3. UI/UX Designer at L&T
#      Location: Lucknow, Industry: Agriculture
#      Required Skills: Tableau, Manual Testing, Medical Coding, Industrial Safety, CSR Implementation, Inventory Management
#   4. Finance Intern at Mahindra
#      Location: City_220, Industry: Logistics
#      Required Skills: Cloud, Supply Chain, Project Management, Logistics, Quality Assurance
#   5. Product Manager at Cognizant
#      Location: City_143, Industry: Logistics
# ...
